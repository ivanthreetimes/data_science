# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

import networkx as nx

# %%
sofia = {"lat": 42.6977,"lng": 23.3219}
m = Basemap(projection="merc", llcrnrlat=41, llcrnrlon=22,urcrnrlat=44.5,urcrnrlon=29, resolution="i")

m.drawcoastlines()
m.drawcountries()
x,y = m(sofia["lng"], sofia["lat"])         #x -> Longitude; y -> Latitude
m.plot([x], [y], "o")
plt.show()

# %%
families = nx.florentine_families_graph()
nx.draw(g, with_labels=True)

# %%
print(nx.shortest_path(families, "Pazzi", "Peruzzi"))
print(nx.shortest_path_length(families, "Pazzi", "Peruzzi"))
# Out:
# ['Pazzi', 'Salviati', 'Medici', 'Barbadori', 'Castellani', 'Peruzzi']
# 5
